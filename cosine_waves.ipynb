# %% [markdown]
# <a href="https://colab.research.google.com/github/alina-bogdanovskaya/Math/blob/elemetary_algebra/cosine_waves.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 20, 145)
k1 = 1
k2 = 1.5
plt.plot(x, np.cos(k1*x))
plt.plot(x, np.cos(k2*x))
